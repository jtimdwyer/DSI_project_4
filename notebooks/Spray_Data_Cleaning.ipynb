# 1599  2011-09-07  NaN  41.992708 -87.808927
# 1600  2011-09-07  NaN  41.992708 -87.808399
# 1601  2011-09-07  NaN  41.992756 -87.807775
# 1602  2011-09-07  NaN  41.992756 -87.807199
# 1603  2011-09-07  NaN  41.996164 -87.813727
# 1604  2011-09-07  NaN  41.995732 -87.813679
# 1605  2011-09-07  NaN  41.994916 -87.813727
# 1606  2011-09-07  NaN  41.992948 -87.813775
# 1607  2011-09-07  NaN  41.996644 -87.811567
# 1608  2011-09-07  NaN  41.996260 -87.811567
# 1609  2011-09-07  NaN  41.995876 -87.811615
# 1610  2011-09-07  NaN  41.995972 -87.810271
# 1611  2011-09-07  NaN  41.995684 -87.810319
# 1612  2011-09-07  NaN  41.994724 -87.810415
# 1613  2011-09-07  NaN  41.993092 -87.810415
#
# [584 rows x 4 columns]

# %%
spray.iloc[11499, :]
# Out:
# Date          2013-08-22
# Time         10:53:16 PM
# Latitude          41.724
# Longitude       -87.6222
# Name: 11499, dtype: object

# %%
spray[spray['Longitude']== -87.615892]
# Out:
# Empty DataFrame
# Columns: [Date, Time, Latitude, Longitude]
# Index: []

# %%
order_groups = spray.groupby(['Latitude', 'Longitude'], as_index=False).count().sort_values('Date', ascending=False)

# %%
order_groups
# Out:
#         Latitude  Longitude  Date  Time
# 11853  41.986460 -87.794225   541   541
# 11499  41.983917 -87.793088     2     2
# 0      41.713925 -87.615892     1     1
# 9533   41.959113 -87.719752     1     1
# 9522   41.959028 -87.728890     1     1
# 9523   41.959052 -87.725095     1     1
# 9524   41.959055 -87.724518     1     1
# 9525   41.959055 -87.711887     1     1
# 9526   41.959070 -87.715542     1     1
# 9527   41.959080 -87.737005     1     1
# 9528   41.959085 -87.711258     1     1
# 9529   41.959090 -87.716798     1     1
# 9530   41.959105 -87.710555     1     1
# 9531   41.959107 -87.722885     1     1
# 9532   41.959112 -87.712832     1     1
# 9534   41.959115 -87.710088     1     1
# 9520   41.959023 -87.729487     1     1
# 9535   41.959123 -87.709648     1     1
# 9536   41.959123 -87.708298     1     1
# 9537   41.959128 -87.720375     1     1
# 9538   41.959137 -87.710652     1     1
# 9539   41.959140 -87.709087     1     1
# 9540   41.959155 -87.708488     1     1
# 9541   41.959183 -87.717968     1     1
# 9542   41.959193 -87.719015     1     1
# 9543   41.959210 -87.710050     1     1
# 9544   41.959215 -87.726288     1     1
# 9545   41.959215 -87.709420     1     1
# 9521   41.959027 -87.712413     1     1
# 9519   41.959020 -87.730042     1     1
# ...          ...        ...   ...   ...
# 4797   41.894853 -87.763522     1     1
# 4798   41.894858 -87.714748     1     1
# 4774   41.894445 -87.756867     1     1
# 4773   41.894435 -87.723573     1     1
# 4772   41.894418 -87.715112     1     1
# 4771   41.894413 -87.710262     1     1
# 4748   41.894045 -87.756855     1     1
# 4749   41.894048 -87.714745     1     1
# 4750   41.894068 -87.715078     1     1
# 4751   41.894077 -87.766728     1     1
# 4752   41.894102 -87.721233     1     1
# 4753   41.894108 -87.715678     1     1
# 4754   41.894118 -87.716298     1     1
# 4755   41.894122 -87.722377     1     1
# 4756   41.894133 -87.707798     1     1
# 4757   41.894140 -87.724800     1     1
# 4758   41.894157 -87.754473     1     1
# 4759   41.894160 -87.767937     1     1
# 4760   41.894223 -87.711547     1     1
# 4761   41.894267 -87.759332     1     1
# 4762   41.894270 -87.709052     1     1
# 4763   41.894273 -87.718747     1     1
# 4764   41.894282 -87.748178     1     1
# 4765   41.894322 -87.713947     1     1
# 4766   41.894333 -87.712617     1     1
# 4767   41.894337 -87.714500     1     1
# 4768   41.894343 -87.760688     1     1
# 4769   41.894380 -87.772148     1     1
# 4770   41.894402 -87.704128     1     1
# 14293  42.395983 -88.095757     1     1
#
# [14294 rows x 4 columns]

# %%
order_groups.loc[11499, :]['Latitude']
# Out:
# 41.9839166666667

# %%
lat_long_count = spray.drop('Time', axis=1).groupby(['Latitude', 'Longitude']).agg(['count'])

lat_long_count.columns

lat_long_count = pd.Series(lat_long_count.values.reshape(1,-1)[0], lat_long_count.index)

lat_long_count.sort_values(ascending=False).head()
# Out:
# Latitude   Longitude
# 41.986460  -87.794225    541
# 41.983917  -87.793088      2
# 41.894413  -87.710262      1
# 41.894380  -87.772148      1
# 41.894343  -87.760688      1
# dtype: int64

# %% [markdown]
# Through manual inspection, we have determined a spray entry which has been duplicated 541 times.  We are going to remove the duplicates from this list.

# %%
mask = (spray['Latitude'] == 41.986460) & (spray['Longitude'] == -87.794225)
spray[mask].shape
# Out:
# (541, 4)

# %%
spray[mask].index[1:]
# Out:
# Int64Index([ 490,  491,  492,  493,  494,  495,  496,  497,  498,  499,
#             ...
#             1020, 1021, 1022, 1023, 1024, 1025, 1026, 1027, 1028, 1029],
#            dtype='int64', length=540)

# %%
spray.drop(spray[mask].index[1:], inplace=True)

# %%
lat_long_count = spray.drop('Time', axis=1).groupby(['Latitude', 'Longitude']).agg(['count'])

lat_long_count = pd.Series(lat_long_count.values.reshape(1,-1)[0], lat_long_count.index)

lat_long_count.sort_values(ascending=False).head()
# Out:
# Latitude   Longitude
# 41.983917  -87.793088    2
# 42.395983  -88.095757    1
# 41.894157  -87.754473    1
# 41.894380  -87.772148    1
# 41.894343  -87.760688    1
# dtype: int64

# %%
mask = (spray['Longitude'] == -87.7930883333333) & (spray['Latitude'] ==  41.9839166666667)
sum(mask)
# Out:
# 2

# %%
spray[mask].index[1:]
# Out:
# Int64Index([485], dtype='int64')

# %%
spray.drop(spray[mask].index[1:], inplace=True)

# %%
lat_long_count = spray.drop('Time', axis=1).groupby(['Latitude', 'Longitude']).agg(['count'])

lat_long_count = pd.Series(lat_long_count.values.reshape(1,-1)[0], lat_long_count.index)

lat_long_count.sort_values(ascending=False).head()
# Out:
# Latitude   Longitude
# 42.395983  -88.095757    1
# 41.894160  -87.767937    1
# 41.894402  -87.704128    1
# 41.894380  -87.772148    1
# 41.894343  -87.760688    1
# dtype: int64

# %%
spray.drop('Time', axis=1, inplace=True)

# %%
spray.to_csv('Spray_Cleaned.csv')
